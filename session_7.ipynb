# %%
a = int(input("enter minute"))
if a>120:
    print("You are true music fan!")
else:
    print("Keep Listening!")
# Out:
# Keep Listening!

# %%
or_am = int(input("enter order amount"))
if or_am > 300:
    print("Eligible for free delivery")
else:
    print("Delivery charges apply")
# Out:
# Eligible for free delivery

# %%
flip_tot = int(input("enter amount"))
if flip_tot > 2000:
    print("you get 10% discount")
elif flip_tot>1000:
    print("you get 5% discount")
else:
    print("no discount available")
# Out:
# you get 10% discount

# %%
point = int(input("enter fantasy points"))
if point>800:
    print("Champions")
elif point>=500 and point<=800:
    print("Top performer")
else:
    print("Keep Trying")
# Out:
# Champions
