# %%
insta_followers = {
    "cristiano" : 675000000,
    "leomessi" : 512000000,
    "selenagomez":404000000,
    "therock":382000000,
    "kyliejenner":382000000
}
print(insta_followers)
print(type(insta_followers))

insta_followers["cristiano"] = 678000000
print(insta_followers)

insta_followers["kohli"] = 778000000
print(insta_followers)

food_prices = {
    "pizza" :300,
    "burger" :150,
    "pasta" : 170,
    "paneer_tikka" : 600,
    "hot_dog" : 120
}

for food, price in food_prices.items():
    if price > 200:
        print(food, price)


flipkart_users = {"kohli_king","roh_hit","princ_gill","sarpanch_shreyas","classy_rahul"}
myntra_users = {"david_beckham","mesi_goat","ronald_legend","ney_jr","yamal_limine"}

print(flipkart_users.intersection(myntra_users))

print(flipkart_users.union(myntra_users))
# Out:
# {'cristiano': 675000000, 'leomessi': 512000000, 'selenagomez': 404000000, 'therock': 382000000, 'kyliejenner': 382000000}
# <class 'dict'>
# {'cristiano': 678000000, 'leomessi': 512000000, 'selenagomez': 404000000, 'therock': 382000000, 'kyliejenner': 382000000}
# {'cristiano': 678000000, 'leomessi': 512000000, 'selenagomez': 404000000, 'therock': 382000000, 'kyliejenner': 382000000, 'kohli': 778000000}
# pizza 300
# paneer_tikka 600
# set()
# {'ronald_legend', 'roh_hit', 'princ_gill', 'classy_rahul', 'sarpanch_shreyas', 'mesi_goat', 'yamal_limine', 'ney_jr', 'david_beckham', 'kohli_king'}
