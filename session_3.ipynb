# %%
spotify_acc = "yug45"
age = 18
height = 180.8
name = "Yug patel"
is_active = "true"
print(age)
print(height)
print(name)
print(is_active)

import numpy as np
a = np.array(["199.6","40","30.5"],dtype=float)
print(a)

score = input("enter score")
sco_run = int(score)
if sco_run == 50:
    print('Half-century!')
else:
    print("Keep Going!")

is_premium ="true"
st = str(is_premium)
print(type(st))
# Out:
# 18
# 180.8
# Yug patel
# true
# [199.6  40.   30.5]
# Half-century!
# <class 'str'>
