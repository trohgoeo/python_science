# %%
a = ["Eatsure","Swiggy","Zomato","BOX8","Domino's"]
for i in a:
    print(i)


step = [1000, 2000, 3000, 4000, 6000, 8000, 9000, 10000, 13000, 15000]

while step:
    current = step.pop(0)

    if current == 13000:
        break

    print(current)



for i in team_name:
    if len(i) > 6:
        continue
    print(i)

dura = [1.23,4.67,4.56,2.34,7.56]
for i in enumerate(dura,start=1):
    print(i)


flip_cart = [300, 600, 200, 400, 100, 20, 0, 400, 200, 300, 0, 1000]

total = 0

for i in flip_cart:
    if i == 0:
        continue

    total += i

    if total > 2000:
        break

    print(total)

print("Final Total:", total)
# Out:
# Eatsure
# Swiggy
# Zomato
# BOX8
# Domino's
# 1000
# 2000
# 3000
# 4000
# 6000
# 8000
# 9000
# 10000
# RCB
# GT
# SRH
# (1, 1.23)
# (2, 4.67)
# (3, 4.56)
# (4, 2.34)
# (5, 7.56)
# 300
# 900
# 1100
# 1500
# 1600
# 1620
# Final Total: 2020
