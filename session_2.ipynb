# %%
# it shows variable and their value which assign to each variable 
item_price = 20000
delivery_fee = 50
coupon_discount = 400
print(item_price)
print(delivery_fee)
print(coupon_discount)

''''
in this it first take user input if price below 1000 it gives else and if above then it gives free delivery
'''
flipkart = "airpord"
price = int(input("enter price"))
if price >1000:
    print("eligible for free delivery")
else:
    print("delivery charges apply")

# ipl match
team_name = "RCB"
run_scored23 = 20000
overs20_played = 20
print(team_name)
print(run_scored23)
print(overs20_played)
# Out:
# 20000
# 50
# 400
# eligible for free delivery
# RCB
# 20000
# 20
