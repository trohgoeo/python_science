# %%
a = 'Flipkart-Sale2024'
print(a.lower().replace("-"," "))

product_name = " OnePlus Nord-CE 3 "
print(product_name.upper().replace("-",":").strip())

product_code = 'ZOMATO-FOOD-2024'
print(product_code.split('-'))

b = 'Spotify_Premium_Offer'
print(b[8:15])



product = 'Myntra Shirt'
price = 799.5
print('Deal: Myntra Shirt is available at ₹799.50 only!')
# Out:
# flipkart sale2024
# ONEPLUS NORD:CE 3
# ['ZOMATO', 'FOOD', '2024']
# Premium
# Deal: Myntra Shirt is available at ₹799.50 only!
