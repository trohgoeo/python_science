# %%
a = [8522014132,9276067008,8887573328,2221840315,1488948767]
print(a)

a.append([1234567890])
print(a)

b=[4567865434,7865435678]
a.extend(b)
print(a)

a.pop()

insta_filter = ("yug_verse","nandu_patel","Namra_patel","Nupur_patel")
# it gives type error because we did not do anything with tupple like append,insert or add it is immutable.

list_order = ["pizza","burger"]
# if tomorrow we will add some other food to zomato so we have to change the list so we used list beacuse it is changable or muttable.
tuple_ipl = ("csk","mi","rr","rcb")
# mostly in this ipl team are fixed they don't change or add new teams so tuple is also immutable and fixed elements once it created so we use tuple here.
# Out:
# [8522014132, 9276067008, 8887573328, 2221840315, 1488948767]
# [8522014132, 9276067008, 8887573328, 2221840315, 1488948767, [1234567890]]
# [8522014132, 9276067008, 8887573328, 2221840315, 1488948767, [1234567890], 4567865434, 7865435678]
